# %%
import pandas as pd
#read in data using pandas
train_df = pd.read_csv("AQI.csv")
#check data has been read in properly
train_df.head()
# Out:
#          Date    SO2    NO2     O3   PM2.5    PM10     AT      WD    WS  \
# 0  09/04/2015  14.93  79.48  10.17   83.02  482.61  30.16  263.99  1.50
# 1  10/04/2015  11.17  77.10  13.88  114.30  442.78  29.81  256.34  1.26
# 2  11/04/2015  28.10  85.62  13.12  251.78  671.70  29.92  160.78  0.97
# 3  12/04/2015  22.88  61.65  10.91   64.32  161.80  24.30  151.32  1.77
# 4  13/04/2015  14.95  53.87  15.89  110.57  247.32  24.91  118.04  2.01
#
#       RH        AQI1        AQI2        AQI3        AQI4        AQI5  DOW  \
# 0  31.26  396.315696  326.702405  265.960000  233.431034  144.805839    4
# 1  36.18  475.049130  396.315696  326.702405  265.960000  233.431034    5
# 2  36.42  417.901739  475.049130  396.315696  326.702405  265.960000    6
# 3  53.08  746.352174  417.901739  475.049130  396.315696  326.702405    7
# 4  58.09  141.397315  746.352174  417.901739  475.049130  396.315696    1
#
#    DOM  DOY  MONTH         AQI
# 0    9   99      4  475.049130
# ...

# %%
#create a dataframe with all training data except the target column
train_X = train_df.drop(columns=['AQI'])
#check that the target variable has been removed
train_X.head()
# Out:
#      SO2    NO2     O3   PM2.5    PM10     AT      WD    WS     RH  \
# 0  14.93  79.48  10.17   83.02  482.61  30.16  263.99  1.50  31.26
# 1  11.17  77.10  13.88  114.30  442.78  29.81  256.34  1.26  36.18
# 2  28.10  85.62  13.12  251.78  671.70  29.92  160.78  0.97  36.42
# 3  22.88  61.65  10.91   64.32  161.80  24.30  151.32  1.77  53.08
# 4  14.95  53.87  15.89  110.57  247.32  24.91  118.04  2.01  58.09
#
#          AQI1        AQI2        AQI3        AQI4        AQI5  DOW  DOM  DOY  \
# 0  396.315696  326.702405  265.960000  233.431034  144.805839    4    9   99
# 1  475.049130  396.315696  326.702405  265.960000  233.431034    5   10  100
# 2  417.901739  475.049130  396.315696  326.702405  265.960000    6   11  101
# 3  746.352174  417.901739  475.049130  396.315696  326.702405    7   12  102
# 4  141.397315  746.352174  417.901739  475.049130  396.315696    1   13  103
#
#    MONTH         AQI
# 0      4  475.049130
# 1      4  417.901739
# 2      4  746.352174
# ...

# %%
#create a dataframe with only the target column
train_y = train_df[['AQI']]

#view dataframe
train_y.tail()
# Out:
#              AQI
# 1206  486.699565
# 1207  496.743043
# 1208  782.881739
# 1209  688.028261
# 1210  614.423913

# %%
from keras.models import Sequential
from keras.layers import Dense
#create model
model = Sequential()

#get number of columns in training data
n_cols = train_X.shape[1]

#add model layers
model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
model.add(Dense(10, activation='relu'))
model.add(Dense(1))

# %%
#compile model using mse as a measure of model performance
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
from keras.callbacks import EarlyStopping
#set early stopping monitor so the model stops training when it won't improve anymore
early_stopping_monitor = EarlyStopping(patience=30)
#train model
model.fit(train_X, train_y, validation_split=0.2, epochs=300, callbacks=[early_stopping_monitor])
# Out:
# Train on 968 samples, validate on 243 samples
# Epoch 1/300
# 968/968 [==============================] - 1s 918us/step - loss: 468318.3585 - val_loss: 176727.5945
# Epoch 2/300
# 968/968 [==============================] - 0s 41us/step - loss: 309234.7978 - val_loss: 98946.4545
# Epoch 3/300
# 968/968 [==============================] - 0s 38us/step - loss: 158154.1742 - val_loss: 27940.4802
# Epoch 4/300
# 968/968 [==============================] - 0s 39us/step - loss: 49513.0647 - val_loss: 18496.5472
# Epoch 5/300
# 968/968 [==============================] - 0s 44us/step - loss: 33872.5890 - val_loss: 13306.7436
# Epoch 6/300
# 968/968 [==============================] - 0s 37us/step - loss: 27531.2512 - val_loss: 11588.1452
# Epoch 7/300
# 968/968 [==============================] - 0s 42us/step - loss: 22511.8404 - val_loss: 8823.2330
# Epoch 8/300
# 968/968 [==============================] - 0s 37us/step - loss: 17660.3319 - val_loss: 7078.3439
# Epoch 9/300
# ...

# %%
#example on how to use our newly trained model on how to make predictions on unseen data (we will pretend our new data is saved in a dataframe called 'test_X').
test_y_predictions = model.predict(train_X)

# %%
l = []
for i in range(1211):
    l.append(((train_y["AQI"][i] - test_y_predictions[i])/train_y["AQI"][i])*100)
    print(str(train_y["AQI"][i]) +" " + str(test_y_predictions[i]) + " " + str(l[i]))
# Out:
# 475.049130434783 [475.2067] [-0.03316757]
# 417.90173913043503 [417.97495] [-0.01751887]
# 746.352173913044 [746.5199] [-0.02247258]
# 141.397315436242 [141.51491] [-0.08316954]
# 267.807931034483 [268.42752] [-0.23135924]
# 352.743164556962 [352.9101] [-0.04732371]
# 296.210689655172 [296.44852] [-0.08028862]
# 416.165652173913 [416.10318] [0.01501073]
# 475.594347826087 [475.68768] [-0.01962234]
# 722.477391304348 [722.5348] [-0.00794115]
# 583.360869565217 [583.21344] [0.02526736]
# 784.7756521739129 [785.1292] [-0.04505449]
# 768.9786956521741 [769.0684] [-0.01166764]
# 612.113913043478 [612.3916] [-0.045369]
# 620.45 [620.61084] [-0.02592112]
# 626.763043478261 [627.03503] [-0.04339322]
# 294.74275862069 [295.13022] [-0.131454]
# 226.06 [226.53041] [-0.2080922]
# 174.06731543624198 [174.5442] [-0.27396464]
# 313.87 [314.27945] [-0.13045348]
# 215.86 [215.85655] [0.00159756]
# 209.33 [209.63261] [-0.14456232]
# 357.898139534884 [358.10062] [-0.05657591]
# ...

# %%
l.sort(reverse = True) 
print(l)
# Out:
# [array([5.603796], dtype=float32), array([4.286892], dtype=float32), array([0.8135155], dtype=float32), array([0.48458347], dtype=float32), array([0.36063486], dtype=float32), array([0.34333214], dtype=float32), array([0.24877816], dtype=float32), array([0.21338028], dtype=float32), array([0.20782922], dtype=float32), array([0.1042579], dtype=float32), array([0.07798324], dtype=float32), array([0.06591759], dtype=float32), array([0.06127818], dtype=float32), array([0.05955677], dtype=float32), array([0.05830006], dtype=float32), array([0.05278508], dtype=float32), array([0.05097736], dtype=float32), array([0.05004239], dtype=float32), array([0.0476687], dtype=float32), array([0.04599348], dtype=float32), array([0.04559729], dtype=float32), array([0.04369524], dtype=float32), array([0.04049226], dtype=float32), array([0.03938011], dtype=float32), array([0.03864008], dtype=float32), array([0.03818155], dtype=float32), array([0.03734912], dtype=float32), array([0.03663829], dtype=float3
# ...

# %%
#training a new model on the same data to show the effect of increasing model capacity

#create model
model_mc = Sequential()

#add model layers
model_mc.add(Dense(200, activation='relu', input_shape=(n_cols,)))
model_mc.add(Dense(200, activation='relu'))
model_mc.add(Dense(200, activation='relu'))
model_mc.add(Dense(1))

#compile model using mse as a measure of model performance
model_mc.compile(optimizer='adam', loss='mean_squared_error')
#train model
model_mc.fit(train_X, train_y, validation_split=0.2, epochs=30, callbacks=[early_stopping_monitor])
# Out:
# Train on 968 samples, validate on 243 samples
# Epoch 1/30
# 968/968 [==============================] - 0s 416us/step - loss: 25357.5620 - val_loss: 3564.6563
# Epoch 2/30
# 968/968 [==============================] - 0s 71us/step - loss: 2167.2211 - val_loss: 510.8836
# Epoch 3/30
# 968/968 [==============================] - 0s 69us/step - loss: 344.8369 - val_loss: 219.2908
# Epoch 4/30
# 968/968 [==============================] - 0s 71us/step - loss: 166.8326 - val_loss: 217.1854
# Epoch 5/30
# 968/968 [==============================] - 0s 72us/step - loss: 176.3719 - val_loss: 136.8891
# Epoch 6/30
# 968/968 [==============================] - 0s 70us/step - loss: 126.4820 - val_loss: 77.2681
# Epoch 7/30
# 968/968 [==============================] - 0s 65us/step - loss: 71.7035 - val_loss: 74.2690
# Epoch 8/30
# 968/968 [==============================] - 0s 70us/step - loss: 67.1109 - val_loss: 45.3552
# Epoch 9/30
# ...

# %%
#example on how to use our newly trained model on how to make predictions on unseen data (we will pretend our new data is saved in a dataframe called 'test_X').
test_y_predictions = model.predict(train_X)

# %%
l = []
for i in range(1215):
    l.append(((train_y["AQI"][i] - test_y_predictions[i])/train_y["AQI"][i])*100)
    print(l[i])
# Out:
# [-0.03316757]
# [-0.01751887]
# [-0.02247258]
# [-0.08316954]
# [-0.23135924]
# [-0.04732371]
# [-0.08028862]
# [0.01501073]
# [-0.01962234]
# [-0.00794115]
# [0.02526736]
# [-0.04505449]
# [-0.01166764]
# [-0.045369]
# [-0.02592112]
# [-0.04339322]
# [-0.131454]
# [-0.2080922]
# [-0.27396464]
# [-0.13045348]
# [0.00159756]
# [-0.14456232]
# [-0.05657591]
# [-0.02035284]
# [0.0090969]
# [-0.00464994]
# [-0.01478279]
# [-0.01951508]
# [-0.02773122]
# [-0.04331054]
# [-0.02474532]
# [-0.02560659]
# [-0.04177893]
# [-0.10318632]
# [-0.05726752]
# [0.00714853]
# [0.00470028]
# [-0.05877961]
# [-0.07639329]
# [-0.02345497]
# [-0.01923551]
# [-0.03848268]
# [-0.00038131]
# [-0.04343738]
# [-0.00720205]
# [-0.07414981]
# [0.00818457]
# [-0.02811337]
# [-0.02151406]
# [0.03938011]
# [-0.06465974]
# [0.00914411]
# [-0.4225547]
# [-0.0382448]
# [-0.12248378]
# [-0.01280399]
# [-0.00413844]
# [-0.04916169]
# [-0.02386563]
# [0.01098977]
# [-0.02771598]
# [-0.06806087]
# [-0.00124445]
# ...

# %%
l.sort(reverse = True) 
print(l)
# Out:
# [array([5.603796], dtype=float32), array([4.286892], dtype=float32), array([0.8135155], dtype=float32), array([0.48458347], dtype=float32), array([0.36063486], dtype=float32), array([0.34333214], dtype=float32), array([0.24877816], dtype=float32), array([0.21338028], dtype=float32), array([0.20782922], dtype=float32), array([0.1042579], dtype=float32), array([0.07798324], dtype=float32), array([0.06591759], dtype=float32), array([0.06127818], dtype=float32), array([0.05955677], dtype=float32), array([0.05830006], dtype=float32), array([0.05278508], dtype=float32), array([0.05097736], dtype=float32), array([0.05004239], dtype=float32), array([0.0476687], dtype=float32), array([0.04599348], dtype=float32), array([0.04559729], dtype=float32), array([0.04369524], dtype=float32), array([0.04049226], dtype=float32), array([0.03938011], dtype=float32), array([0.03864008], dtype=float32), array([0.03818155], dtype=float32), array([0.03734912], dtype=float32), array([0.03663829], dtype=float3
# ...
